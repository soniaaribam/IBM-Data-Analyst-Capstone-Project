# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 153.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 154.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 143.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 157.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 93.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 140.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
selected_columns = ['MainBranch', 'Employment', 'RemoteWork']
duplicate_rows = df[df.duplicated(keep=False)]
num_duplicates = duplicate_rows.shape[0]
print(f"Number of duplicate rows: {num_duplicates}")
if not duplicate_rows.empty:
    print("\nFirst few duplicate rows:")
    print(duplicate_rows.head())
else:
    print("No duplicate rows found.")
# Out:
# Number of duplicate rows: 40
#
# First few duplicate rows:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
## Write your code here
if not duplicate_subset.empty:
    identical_values = duplicate_subset.mode().iloc[0]  # Get the most frequent values in each column
    print("\nMost frequently occurring values in duplicate rows:")
    print(identical_values)
else:
    print("No duplicate rows available for analysis.")
# Out:
# Most frequently occurring values in duplicate rows:
# ResponseId                                                1
# MainBranch                   I am a developer by profession
# Age                                         25-34 years old
# Employment                              Employed, full-time
# RemoteWork             Hybrid (some remote, some in-person)
#                                        ...
# JobSatPoints_11                                         0.0
# SurveyLength                          Appropriate in length
# SurveyEase                                             Easy
# ConvertedCompYearly                                 64444.0
# JobSat                                                  8.0
# Name: 0, Length: 114, dtype: object

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
## Write your code here
if not duplicate_rows.empty:
    plt.figure(figsize=(12, 6))
    duplicate_rows['Country'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title('Distribution of Duplicate Rows by Country')
    plt.xlabel('Country')
    plt.ylabel('Number of Duplicates')
    plt.xticks(rotation=90)
    plt.show()
else:
    print("No duplicate rows found for visualization.")

if not duplicate_rows.empty:
    plt.figure(figsize=(8, 8))
    duplicate_rows['Employment'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightblue', 'lightgreen'])
    plt.title('Distribution of Duplicate Rows by Employment Type')
    plt.ylabel('')  # Hide y-label
    plt.show()
else:
    print("No duplicate rows found for visualization.")

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here
critical_columns = ['MainBranch', 'Employment', 'RemoteWork']


subset_duplicates = df[df.duplicated(subset=critical_columns, keep=False)]
print(f"Number of duplicate rows based on {critical_columns}: {subset_duplicates.shape[0]}")
df_cleaned = df.drop_duplicates(subset=critical_columns, keep='first')
print(f"Original dataset size: {df.shape[0]} rows")
print(f"Dataset size after removing duplicates: {df_cleaned.shape[0]} rows")
remaining_duplicates = df_cleaned[df_cleaned.duplicated(subset=critical_columns, keep=False)]
print(f"Remaining duplicate rows after cleaning: {remaining_duplicates.shape[0]}")
# Out:
# Number of duplicate rows based on ['MainBranch', 'Employment', 'RemoteWork']: 65290
# Original dataset size: 65457 rows
# Dataset size after removing duplicates: 561 rows
# Remaining duplicate rows after cleaning: 0

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# Step 1: Identifying Duplicate Rows
# Used duplicated() to detect and count duplicate rows.
# Analyzed the first few duplicate rows to understand their structure.
# Step 2: Analyzing Duplicate Characteristics
# Focused on key columns (MainBranch, Employment, RemoteWork) to identify patterns.
# Determined which attributes frequently contain identical values.
# Step 3: Visualizing Duplicate Distribution
# Used bar charts to show duplicate distribution by Country.
# Used pie charts to illustrate duplicate distribution by Employment Type.
# Step 4: Removing Duplicates Strategically
# Retained uniqueness based on critical columns instead of full row duplication.
# Used drop_duplicates() to keep the first occurrence.
# Step 5: Verification
# Checked for remaining duplicates after removal to ensure data integrity.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# Reasoning Behind Selecting Specific Columns for Identifying and Removing Duplicates
# When handling duplicates, removing entire duplicate rows may not always be the best approach, as some columns (e.g., timestamps, unique IDs) may cause technically non-duplicate rows while the core information remains identical. Instead, we selected key columns that define meaningful uniqueness in the dataset.
#
# 1. Selecting Key Columns for Identifying Duplicates
# We focused on columns that provide substantial information about a respondent's background and employment status:
#
# MainBranch: Defines whether a respondent primarily works as a developer, student, or another role in the tech industry. This helps in understanding if multiple entries represent the same category of professionals.
#
# Employment: Indicates whether the respondent is employed full-time, part-time, or unemployed. Repeated responses from the same employment category can signal redundancy.
#
# RemoteWork: Shows whether the respondent works remotely, on-site, or hybrid. This is crucial in identifying duplicate entries with the same employment structure.
#
# 2. Why These Columns?
# These fields capture essential professional characteristics while excluding non-essential variations like timestamps or unique IDs.
# If multiple rows share the same values in these columns, it’s likely that the entries represent the same respondent or redundant responses.
# Helps prevent accidental removal of similar but distinct records (e.g., two employees from the same company but in different roles).
# 3. Strategic Duplicate Removal
# Instead of removing full-row duplicates, we dropped duplicates based on these selected columns to ensure:
# ✅ Retention of unique and meaningful data.
# ✅ Prevention of unnecessary data loss by considering only critical attributes.
# ✅ A cleaned dataset that is reliable for further analysis.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
